# %%
import pandas as pd
df = pd.read_csv('C:/Users/icorw\iCloudDrive/DST9/data_sf.csv')

# %% [markdown]
# #### Задача 1

# %%
pivot = df.pivot_table(index='Club', columns='Nationality', values='Wage', aggfunc='sum', fill_value=0)

# %%
pivot.loc['AS Monaco']['Russia']
# Out:
# 61000

# %% [markdown]
# #### Задача 2

# %%
s = df[['SprintSpeed', 'Position']].pivot_table(index='Position', values='SprintSpeed', 
              aggfunc='mean')
s.loc[s.index.intersection(['RB', 'LM', 'RM', 'CF', 'RWM', 'RS', 'RWM'])].\
      sort_values(['SprintSpeed'], ascending=False).head(3)
# Out:
#     SprintSpeed
# RM    74.943864
# LM    74.211538
# RS    71.991228

# %% [markdown]
# #### Задача 3

# %%
p = df.pivot_table(index='Club', columns='Position', values='SprintSpeed', aggfunc='mean')
p['ST'].sort_values(ascending=False)
# Out:
# Club
# Vitória            91.000000
# Sydney FC          88.000000
# CD Lugo            87.000000
# Brøndby IF         84.666667
# Leicester City     84.500000
#                      ...
# Valencia CF              NaN
# VfL Bochum 1848          NaN
# VfL Wolfsburg            NaN
# Waterford FC             NaN
# Wigan Athletic           NaN
# Name: ST, Length: 650, dtype: float64

# %%
df.pivot_table(index='Club', columns='Position', values='SprintSpeed', aggfunc='mean', margins=True)
# Out:
# Position                     CAM         CB        CDM         CF         CM  \
# Club
#  SSV Jahn Regensburg         NaN  46.600000  82.000000        NaN  61.000000
# 1. FC Heidenheim 1846  68.000000  61.333333        NaN        NaN  68.000000
# 1. FC Kaiserslautern         NaN  59.000000  65.666667        NaN        NaN
# 1. FC Köln                   NaN  60.000000  32.000000        NaN  68.500000
# 1. FC Magdeburg              NaN  60.000000        NaN  64.000000        NaN
# ...                          ...        ...        ...        ...        ...
# Çaykur Rizespor        74.000000  58.000000  62.800000        NaN        NaN
# Örebro SK                    NaN  60.750000        NaN        NaN  63.000000
# Östersunds FK          67.000000  76.000000        NaN  77.000000  56.333333
# Śląsk Wrocław                NaN  62.000000  66.666667        NaN  72.000000
# All                    68.236967  57.734854  60.813314  69.803922  64.299906
#
# ...
