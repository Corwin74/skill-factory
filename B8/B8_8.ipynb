# %%
import pandas as pd
data = pd.read_excel("./nakladnaya.xls", header=None, skiprows=2)

# %%
data2 = data.dropna(how='all')

# %%
len(data2)
# Out:
# 15

# %%
data
# Out:
#     0                                  1   \
# 0  NaN                                NaN
# 1  NaN                                NaN
# 2  NaN                  Грузоотправитель:
# 3  NaN                                NaN
# 4  NaN                   Грузополучатель:
# 5  NaN                                NaN
# 6  NaN  Основание для отпуска: Договор №
# 7  NaN                                NaN
# 8  NaN                                NaN
# 9  NaN                                  №
# 10 NaN                                п/п
# 11 NaN                                  1
# 12 NaN                                  2
# 13 NaN                                NaN
# 14 NaN                                NaN
# 15 NaN                                NaN
# 16 NaN                                NaN
# 17 NaN                                NaN
# 18 NaN                                NaN
# 19 NaN                                NaN
# 20 NaN                                NaN
# ...

# %%
data2.iloc[6:8, [1, 2, 6, 9, 11, 12]]
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
data2.iloc[6:8, [0, 2, 6, 9, 11, 12]]
# Out:
#     0                      2   6   9     11     12
# 11 NaN  Велосипед "Спринтер"   шт   5  9000  45000
# 12 NaN    Велосипед "Малютка"  шт  10  3500  35000

# %%
data2.iloc[6:8, :].dropna(axis=1, how='all')
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %%
data2.iloc[0, 4].split('от')[0]
# Out:
# '№ 5764809  '

# %%
data.iloc[0, 4][2:9]
# Out:
# '5764809'
