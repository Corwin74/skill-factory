# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import matplotlib.mlab as mlab
# %matplotlib inline
df = pd.read_csv('framingham.csv')

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df['diabetes'].value_counts()
# Out:
# 0    3559
# 1      99
# Name: diabetes, dtype: int64

# %%
99/(3359+99)
# Out:
# 0.028629265471370735

# %%
df.groupby(['diabetes', 'TenYearCHD']).count()
# Out:
#                      male   age  education  currentSmoker  cigsPerDay  BPMeds  \
# diabetes TenYearCHD
# 0        0           3037  3037       3037           3037        3037    3037
#          1            522   522        522            522         522     522
# 1        0             64    64         64             64          64      64
#          1             35    35         35             35          35      35
#
#                      prevalentStroke  prevalentHyp  totChol  sysBP  diaBP  \
# diabetes TenYearCHD
# 0        0                      3037          3037     3037   3037   3037
#          1                       522           522      522    522    522
# 1        0                        64            64       64     64     64
#          1                        35            35       35     35     35
#
#                       BMI  heartRate  glucose
# diabetes TenYearCHD
# 0        0           3037       3037     3037
#          1            522        522      522
# 1        0             64         64       64
#          1             35         35       35

# %%
35/99
# Out:
# 0.35353535353535354

# %%
522/(522+3037)
# Out:
# 0.14667041303737005

# %%
df.groupby(['TenYearCHD', 'diabetes', ]).count()
# Out:
#                      male   age  education  currentSmoker  cigsPerDay  BPMeds  \
# TenYearCHD diabetes
# 0          0         3037  3037       3037           3037        3037    3037
#            1           64    64         64             64          64      64
# 1          0          522   522        522            522         522     522
#            1           35    35         35             35          35      35
#
#                      prevalentStroke  prevalentHyp  totChol  sysBP  diaBP  \
# TenYearCHD diabetes
# 0          0                    3037          3037     3037   3037   3037
#            1                      64            64       64     64     64
# 1          0                     522           522      522    522    522
#            1                      35            35       35     35     35
#
#                       BMI  heartRate  glucose
# TenYearCHD diabetes
# 0          0         3037       3037     3037
#            1           64         64       64
# 1          0          522        522      522
#            1           35         35       35

# %%
35/(35+522)
# Out:
# 0.06283662477558348

# %%
64/(64+3037)
# Out:
# 0.020638503708481134

# %%
df.groupby(['diabetes']).median()
# Out:
#           male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# diabetes
# 0            0   48        2.0              0         0.0     0.0
# 1            0   56        1.0              0         0.0     0.0
#
#           prevalentStroke  prevalentHyp  totChol  sysBP  diaBP    BMI  \
# diabetes
# 0                       0             0    234.0  128.0   82.0  25.35
# 1                       0             1    240.0  142.0   85.0  27.73
#
#           heartRate  glucose  TenYearCHD
# diabetes
# 0              75.0     77.0           0
# 1              78.0    145.0           0

# %%
df.groupby(['diabetes']).mean()
# Out:
#               male        age  education  currentSmoker  cigsPerDay    BPMeds  \
# diabetes
# 0         0.442540  49.396179   1.987075       0.492554    9.098904  0.028941
# 1         0.484848  55.151515   1.737374       0.363636    6.383838  0.080808
#
#           prevalentStroke  prevalentHyp     totChol       sysBP      diaBP  \
# diabetes
# 0                0.005620      0.305423  236.491430  131.992835  82.815819
# 1                0.010101      0.535354  249.656566  145.949495  86.555556
#
#                 BMI  heartRate     glucose  TenYearCHD
# diabetes
# 0         25.722456  75.608879   79.402079    0.146670
# 1         27.952222  80.111111  169.959596    0.353535

# %%
fig, ax = plt.subplots(figsize=(14, 14))
sn.heatmap(df[df['TenYearCHD']==1].corr(), annot=True)
